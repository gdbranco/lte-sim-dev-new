# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
tipo = "DelayVariavel/P50_50/"
base = "../../../../Simulations/SingleCell/" + tipo
graphicsbase = "../pdfs/" + tipo
until = 21
users = 51
scheds = 9
import sys
sys.path.append("..")
from LTEParser import LTEParser
parser = LTEParser()
files = parser.getFiles(base, graphicsbase, scheds, users, until)
metrics = {
    "VIDEO":{
        "GPUTS": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "FAIR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "DELAY": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "JITTER": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "PLR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []}
    },
    "VOICE":{
       "GPUTS": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "FAIR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "DELAY": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "JITTER": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "PLR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []}
    },
    "WEB":{
       "GPUTS": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "FAIR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "DELAY": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "JITTER": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "PLR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []}
    },
    "CBR":{
       "GPUTS": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "FAIR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "DELAY": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "JITTER": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []},
        "PLR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []}
    },
    "GERAL": {
      "PLR": {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7:[], 8: []}
    }
}
for sched in range(1, 9):
    for ue in range(10, users, 10):
        info = parser.parse(files[sched][ue], 100)
        #VIDEO
        metrics["VIDEO"]["GPUTS"][sched].append(info[0])
        metrics["VIDEO"]["FAIR"][sched].append(info[1])
        metrics["VIDEO"]["DELAY"][sched].append(info[2])
        metrics["VIDEO"]["JITTER"][sched].append(info[3])
        metrics["VIDEO"]["PLR"][sched].append(info[4])
        #VOICE
        metrics["VOICE"]["GPUTS"][sched].append(info[5])
        metrics["VOICE"]["FAIR"][sched].append(info[6])
        metrics["VOICE"]["DELAY"][sched].append(info[7])
        metrics["VOICE"]["JITTER"][sched].append(info[8])
        metrics["VOICE"]["PLR"][sched].append(info[9])
        #WEB
        metrics["WEB"]["GPUTS"][sched].append(info[10])
        metrics["WEB"]["FAIR"][sched].append(info[11])
        metrics["WEB"]["DELAY"][sched].append(info[12])
        metrics["WEB"]["JITTER"][sched].append(info[13])
        metrics["WEB"]["PLR"][sched].append(info[14])
        #CBR
        metrics["CBR"]["GPUTS"][sched].append(info[15])
        metrics["CBR"]["FAIR"][sched].append(info[16])
        metrics["CBR"]["DELAY"][sched].append(info[17])
        metrics["CBR"]["JITTER"][sched].append(info[18])
        metrics["CBR"]["PLR"][sched].append(info[19])
        #GERAL
        metrics["GERAL"]["PLR"][sched].append(info[20])
    #VIDEO
for app in metrics:
    for metric in metrics[app]:
        for sched in metrics[app][metric]:
            metrics[app][metric][sched] = np.array(metrics[app][metric][sched], dtype=np.float32)
# Out:
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_10_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_20_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_30_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_40_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_1_UE_50_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_10_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_20_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_30_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_40_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_2_UE_50_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_10_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_20_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_30_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_40_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_3_UE_50_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_10_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_20_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_30_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_40_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_4_UE_50_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_10_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_20_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_5_UE_30_10.gz
# 	Parsing ...Done
# ...
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_30_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_40_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_7_UE_50_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_10_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_20_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_30_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_40_20.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_1.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_2.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_3.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_4.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_5.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_6.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_7.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_8.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_9.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_10.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_11.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_12.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_13.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_14.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_15.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_16.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_17.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_18.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_19.gz
# 	Parsing ...Done
# Opening file: ../../../../Simulations/SingleCell/DelayVariavel/P50_50/SCHED_8_UE_50_20.gz
# 	Parsing ...Done

# %% [markdown]
# # VIDEO
# ## GPUT

# %%
MEGAVIDEO = {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
for sched in metrics["VIDEO"]["GPUTS"]:
    MEGAVIDEO[sched] = np.true_divide(metrics["VIDEO"]["GPUTS"][sched], 1e+6)

# %%
dfGPUTVIDEO = pd.DataFrame({'PF': MEGAVIDEO[1],
                       'FLS': MEGAVIDEO[4], 'EXPR': MEGAVIDEO[5], 'LOGR': MEGAVIDEO[6],
                        'EXPFLS': MEGAVIDEO[7], 'LOGFLS': MEGAVIDEO[8]},
                      index=[10,20,30,40,50])
plot = dfGPUTVIDEO.plot(rot=0, marker='o')
fig = plot.get_figure()
fig.savefig(graphicsbase + "GPUTVideo.pdf", bbox_inches='tight')

# %%
dfGPUTVIDEO
# Out:
#           PF       FLS      EXPR      LOGR    EXPFLS    LOGFLS
# 10  0.697357  0.684066  0.693466  0.694983  0.688139  0.680693
# 20  1.124263  1.081772  1.137291  1.115092  1.121233  1.104241
# 30  0.933158  1.516039  1.600770  1.558054  1.566327  1.550440
# 40  0.359734  1.625621  1.644714  1.559516  1.610947  1.629614
# 50  0.131873  1.506945  1.321789  1.289735  1.389788  1.250533

# %% [markdown]
# ## Delay

# %%
dfDELAYVIDEO = pd.DataFrame({'PF': metrics["VIDEO"]["DELAY"][1],
                            'FLS': metrics["VIDEO"]["DELAY"][4], 'EXPR': metrics["VIDEO"]["DELAY"][5],
                             'LOGR': metrics["VIDEO"]["DELAY"][6], 'EXPFLS': metrics["VIDEO"]["DELAY"][7]
                            ,'LOGFLS': metrics["VIDEO"]["DELAY"][8]},
                           index=[10,20,30,40,50])
plot = dfDELAYVIDEO.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase +"DelayVideoPF.pdf", bbox_inches='tight')

# %%
dfDELAYVIDEO = pd.DataFrame({'FLS': metrics["VIDEO"]["DELAY"][4], 'EXPR': metrics["VIDEO"]["DELAY"][5],
                             'LOGR': metrics["VIDEO"]["DELAY"][6], 'EXPFLS': metrics["VIDEO"]["DELAY"][7],
                            'LOGFLS': metrics["VIDEO"]["DELAY"][8]},
                           index=[10,20,30,40,50])
plot = dfDELAYVIDEO.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "DelayVideo.pdf", bbox_inches='tight')

# %% [markdown]
# ## JITTER

# %%
dfJITTERVIDEO = pd.DataFrame({'PF': metrics["VIDEO"]["JITTER"][1],'FLS': metrics["VIDEO"]["JITTER"][4],
                              'EXPR': metrics["VIDEO"]["JITTER"][5], 'LOGR': metrics["VIDEO"]["JITTER"][6],
                              'EXPFLS': metrics["VIDEO"]["JITTER"][7],'LOGFLS': metrics["VIDEO"]["JITTER"][8]},
                           index=[10,20,30,40,50])
plot = dfJITTERVIDEO.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "JitterVideoPF.pdf", bbox_inches='tight')

# %%
dfJITTERVIDEO = pd.DataFrame({'FLS': metrics["VIDEO"]["JITTER"][4], 'EXPR': metrics["VIDEO"]["JITTER"][5],
                            'LOGR': metrics["VIDEO"]["JITTER"][6], 'EXPFLS': metrics["VIDEO"]["JITTER"][7],
                             'LOGFLS': metrics["VIDEO"]["JITTER"][8]},
                           index=[10,20,30,40,50])
plot = dfJITTERVIDEO.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "JitterVideo.pdf", bbox_inches='tight')

# %% [markdown]
# ## FAIRNESS

# %%
dfFAIRVIDEO = pd.DataFrame({'PF': metrics["VIDEO"]["FAIR"][1], 'FLS': metrics["VIDEO"]["FAIR"][4],
                            'EXPR': metrics["VIDEO"]["FAIR"][5], 'LOGR': metrics["VIDEO"]["FAIR"][6],
                            'EXPFLS': metrics["VIDEO"]["FAIR"][7], 'LOGFLS': metrics["VIDEO"]["FAIR"][8]},
                           index=[10,20,30,40,50])
plot = dfFAIRVIDEO.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "FairnessVideo.pdf", bbox_inches='tight')

# %% [markdown]
# ## PLR

# %%
dfPLRVIDEO = pd.DataFrame({'PF': metrics["VIDEO"]["PLR"][1], 'FLS': metrics["VIDEO"]["PLR"][4],
                           'EXPR': metrics["VIDEO"]["PLR"][5], 'LOGR': metrics["VIDEO"]["PLR"][6],
                          'EXPFLS': metrics["VIDEO"]["PLR"][7], 'LOGFLS': metrics["VIDEO"]["PLR"][8]},
                           index=[10,20,30,40,50])
plot = dfPLRVIDEO.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "PacketLossVideo.pdf", bbox_inches='tight')

# %% [markdown]
# # VOIP
# ## GPUT

# %%
MEGAVOIP = {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
for sched in metrics['VOICE']['GPUTS']:
    MEGAVOIP[sched] = np.true_divide(metrics['VOICE']['GPUTS'][sched], 1e+6)

# %%
dfGPUTVOICE = pd.DataFrame({'PF': MEGAVOIP[1], 'FLS': MEGAVOIP[4],
                            'EXPR': MEGAVOIP[5], 'LOGR': MEGAVOIP[6],
                            'EXPFLS': MEGAVOIP[7], 'LOGFLS': MEGAVOIP[8]},
                      index=[10,20,30,40,50])
plot = dfGPUTVOICE.plot(rot=0, marker='o')
fig = plot.get_figure()
fig.savefig(graphicsbase + "GPUTVoIP.pdf", bbox_inches='tight')

# %% [markdown]
# ## Delay

# %%
dfDELAYVOICE = pd.DataFrame({'PF': metrics['VOICE']['DELAY'][1], 'FLS': metrics['VOICE']['DELAY'][4],
                             'EXPR': metrics['VOICE']['DELAY'][5], 'LOGR': metrics['VOICE']['DELAY'][6],
                            'EXPFLS': metrics['VOICE']['DELAY'][7], 'LOGFLS': metrics['VOICE']['DELAY'][8]},
                           index=[10,20,30,40,50])
plot = dfDELAYVOICE.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "DelayVoIPPF.pdf", bbox_inches='tight')

# %% [markdown]
# ## Jitter

# %%
dfJITTERVOICE = pd.DataFrame({'PF': metrics['VOICE']['JITTER'][1], 'FLS': metrics['VOICE']['JITTER'][4],
                              'EXPR': metrics['VOICE']['JITTER'][5], 'LOGR': metrics['VOICE']['JITTER'][6],
                             'EXPFLS': metrics['VOICE']['JITTER'][7], 'LOGFLS': metrics['VOICE']['JITTER'][8]},
                           index=[10,20,30,40,50])
plot = dfJITTERVOICE.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "JitterVoIPPF.pdf", bbox_inches='tight')

# %% [markdown]
# ## FAIRNESS

# %%
dfFAIRVOICE = pd.DataFrame({'PF': metrics['VOICE']['FAIR'][1], 'FLS': metrics['VOICE']['FAIR'][4],
                            'EXPR': metrics['VOICE']['FAIR'][5], 'LOGR': metrics['VOICE']['FAIR'][6],
                           'EXPFLS': metrics['VOICE']['FAIR'][7], 'LOGFLS': metrics['VOICE']['FAIR'][8]},
                           index=[10,20,30,40,50])
plot = dfFAIRVOICE.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "FairnessVoice.pdf", bbox_inches='tight')

# %% [markdown]
# ## PLR

# %%
dfPLRVOICE = pd.DataFrame({'PF': metrics['VOICE']['PLR'][1], 'FLS': metrics['VOICE']['PLR'][4],
                           'EXPR': metrics['VOICE']['PLR'][5], 'LOGR': metrics['VOICE']['PLR'][6],
                          'EXPFLS': metrics['VOICE']['PLR'][7], 'LOGFLS': metrics['VOICE']['PLR'][8]},
                           index=[10,20,30,40,50])
plot = dfPLRVOICE.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "PacketLossVoice.pdf", bbox_inches='tight')

# %% [markdown]
# # WEB
# ## GPUT

# %%
MEGAWEB = {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
for sched in metrics["WEB"]["GPUTS"]:
    MEGAWEB[sched] = np.true_divide(metrics["WEB"]["GPUTS"][sched], 1e+6)

# %%
dfGPUTWEB = pd.DataFrame({'PF': MEGAWEB[1],
                       'FLS': MEGAWEB[4], 'EXPR': MEGAWEB[5], 'LOGR': MEGAWEB[6],
                        'EXPFLS': MEGAWEB[7], 'LOGFLS': MEGAWEB[8]},
                      index=[10,20,30,40,50])
plot = dfGPUTWEB.plot(rot=0, marker='o')
fig = plot.get_figure()
fig.savefig(graphicsbase + "GPUTWeb.pdf", bbox_inches='tight')

# %% [markdown]
# ## Delay

# %%
dfDELAYWEB = pd.DataFrame({'PF': metrics["WEB"]["DELAY"][1],
                            'FLS': metrics["WEB"]["DELAY"][4], 'EXPR': metrics["WEB"]["DELAY"][5], 'LOGR': metrics["WEB"]["DELAY"][6],
                             'EXPFLS': metrics["WEB"]["DELAY"][7], 'LOGFLS': metrics["WEB"]["DELAY"][8]},
                           index=[10,20,30,40,50])
plot = dfDELAYWEB.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "DelayWeb.pdf", bbox_inches='tight')

# %% [markdown]
# ## Jitter

# %%
dfJITTERWEB = pd.DataFrame({'PF': metrics["WEB"]["JITTER"][1],
                            'FLS': metrics["WEB"]["JITTER"][4], 'EXPR': metrics["WEB"]["JITTER"][5], 'LOGR': metrics["WEB"]["JITTER"][6],
                            'EXPFLS': metrics["WEB"]["JITTER"][7], 'LOGFLS': metrics["WEB"]["JITTER"][8]},
                           index=[10,20,30,40,50])
plot = dfJITTERWEB.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "JitterWebPF.pdf", bbox_inches='tight')

# %% [markdown]
# ## FAIRNESS

# %%
dfFAIRWEB = pd.DataFrame({'PF': metrics["WEB"]["FAIR"][1],
                            'FLS': metrics["WEB"]["FAIR"][4], 'EXPR': metrics["WEB"]["FAIR"][5], 'LOGR': metrics["WEB"]["FAIR"][6],
                            'EXPFLS': metrics["WEB"]["FAIR"][7], 'LOGFLS': metrics["WEB"]["FAIR"][8]},
                           index=[10,20,30,40,50])
plot = dfFAIRWEB.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "FairnessWeb.pdf", bbox_inches='tight')

# %% [markdown]
# ## PLR

# %%
dfPLRWEB = pd.DataFrame({'PF': metrics["WEB"]["PLR"][1],
                            'FLS': metrics["WEB"]["PLR"][4], 'EXPR': metrics["WEB"]["PLR"][5], 'LOGR': metrics["WEB"]["PLR"][6],
                           'EXPFLS': metrics["WEB"]["PLR"][7], 'LOGFLS': metrics["WEB"]["PLR"][8]},
                           index=[10,20,30,40,50])
plot = dfPLRWEB.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "PacketLossWeb.pdf", bbox_inches='tight')

# %% [markdown]
# # CBR
# ## GPUT

# %%
MEGACBR = {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
for sched in metrics["CBR"]["GPUTS"]:
    MEGACBR[sched] = np.true_divide(metrics["CBR"]["GPUTS"][sched], 1e+6)

# %%
dfGPUTCBR = pd.DataFrame({'PF': MEGACBR[1],
                       'FLS': MEGACBR[4], 'EXPR': MEGACBR[5], 'LOGR': MEGACBR[6],
                        'EXPFLS': MEGACBR[7], 'LOGFLS': MEGACBR[8]},
                      index=[10,20,30,40,50])
plot = dfGPUTCBR.plot(rot=0, marker='o')
fig = plot.get_figure()
fig.savefig(graphicsbase + "GPUTCBR.pdf", bbox_inches='tight')

# %% [markdown]
# ## Delay

# %%
dfDELAYCBR = pd.DataFrame({'PF': metrics["CBR"]["DELAY"][1],
                            'FLS': metrics["CBR"]["DELAY"][4], 'EXPR': metrics["CBR"]["DELAY"][5], 'LOGR': metrics["CBR"]["DELAY"][6],
                             'EXPFLS': metrics["CBR"]["DELAY"][7], 'LOGFLS': metrics["CBR"]["DELAY"][8]},
                           index=[10,20,30,40,50])
plot = dfDELAYCBR.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "DelayCBR.pdf", bbox_inches='tight')

# %% [markdown]
# ## Jitter

# %%
dfJITTERCBR = pd.DataFrame({'PF': metrics["CBR"]["JITTER"][1],
                            'FLS': metrics["CBR"]["JITTER"][4], 'EXPR': metrics["CBR"]["JITTER"][5], 'LOGR': metrics["CBR"]["JITTER"][6],
                            'EXPFLS': metrics["CBR"]["JITTER"][7], 'LOGFLS': metrics["CBR"]["JITTER"][8]},
                           index=[10,20,30,40,50])
plot = dfJITTERCBR.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "JitterCBRPF.pdf", bbox_inches='tight')

# %% [markdown]
# ## FAIRNESS

# %%
dfFAIRCBR = pd.DataFrame({'PF': metrics["CBR"]["FAIR"][1], 
                            'FLS': metrics["CBR"]["FAIR"][4], 'EXPR': metrics["CBR"]["FAIR"][5], 'LOGR': metrics["CBR"]["FAIR"][6],
                            'EXPFLS': metrics["CBR"]["FAIR"][7], 'LOGFLS': metrics["CBR"]["FAIR"][8]},
                           index=[10,20,30,40,50])
plot = dfFAIRCBR.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "FairnessCBR.pdf", bbox_inches='tight')

# %% [markdown]
# ## PLR

# %%
dfPLRCBR = pd.DataFrame({'PF': metrics["CBR"]["PLR"][1],
                            'FLS': metrics["CBR"]["PLR"][4], 'EXPR': metrics["CBR"]["PLR"][5], 'LOGR': metrics["CBR"]["PLR"][6],
                           'EXPFLS': metrics["CBR"]["PLR"][7], 'LOGFLS': metrics["CBR"]["PLR"][8]},
                           index=[10,20,30,40,50])
plot = dfPLRCBR.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "PacketLossCBR.pdf", bbox_inches='tight')

# %% [markdown]
# # Loss Ratio

# %%
averagePacketLoss = {}
for key in metrics["GERAL"]["PLR"]:
    averagePacketLoss[key] = []
    for i in range(0, 5):
        average = sum(metrics["GERAL"]["PLR"][key][i])/len(metrics["GERAL"]["PLR"][key][i])
        averagePacketLoss[key].append(average)

# %%
dfLossRatio = pd.DataFrame({'PF': averagePacketLoss[1],
                            'FLS': averagePacketLoss[4], 'EXPR': averagePacketLoss[5], 'LOGR': averagePacketLoss[6],
                           'EXPFLS': averagePacketLoss[7], 'LOGFLS': averagePacketLoss[8]},
                           index=[10,20,30,40,50])
plot = dfLossRatio.plot.bar(rot=0)
fig = plot.get_figure()
fig.savefig(graphicsbase + "PacketLossRatio.pdf", bbox_inches='tight')

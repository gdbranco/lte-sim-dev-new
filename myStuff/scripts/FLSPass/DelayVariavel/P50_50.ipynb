# %%
import sys
sys.path.append("../..")
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
tipo = "FLSPass/DelayVariavel/P50_50/"
base = "../../../../../Simulations/SingleCell/" + tipo
graphicsbase = "../../pdfs/" + tipo
until = 21
users = 51
scheds = 9
from LTEParser import LTEParser
parser = LTEParser()
metrics = parser.parse(base, graphicsbase, scheds, users, until, 100)
from LTEParser import Graphics
graphicWriter = Graphics(graphicsbase, metrics)
metrics
# Out:
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_1.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_2.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_3.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_4.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_5.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_6.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_7.gz
# 	Parsing ...Done
# Opening file: ../../../../../Simulations/SingleCell/FLSPass/DelayVariavel/P50_50/SCHED_1_UE_10_8.gz
# 	Parsing ...Done
# ...

# %% [markdown]
# # VIDEO

# %%
kind = "VIDEO"

# %%
graphicWriter.gputFile(kind, True, True)

# %%
graphicWriter.gputFile(kind, True, False)

# %%
graphicWriter.delayFile(kind, True, True)

# %%
graphicWriter.delayFile(kind, True, False)

# %%
graphicWriter.delayFile(kind, False, True)

# %%
graphicWriter.delayFile(kind, False, False)

# %%
graphicWriter.jitterFile(kind, True, True)

# %%
graphicWriter.jitterFile(kind, True, False)

# %%
graphicWriter.jitterFile(kind, False, True)

# %%
graphicWriter.jitterFile(kind, False, False)

# %%
graphicWriter.fairnessFile(kind, True, True)

# %%
graphicWriter.fairnessFile(kind, True, False)

# %%
graphicWriter.plrFile(kind, True, True)

# %%
graphicWriter.plrFile(kind, True, False)

# %% [markdown]
# # VOICE

# %%
kind = "VOICE"

# %%
graphicWriter.gputFile(kind, True, True)

# %%
graphicWriter.delayFile(kind, True, True)

# %%
graphicWriter.jitterFile(kind, True, True)

# %%
graphicWriter.fairnessFile(kind, True, True)

# %%
graphicWriter.plrFile(kind, True, True)

# %% [markdown]
# # WEB

# %%
kind = "WEB"

# %%
graphicWriter.gputFile(kind, True, True)

# %%
graphicWriter.gputFile(kind, True, False)

# %%
graphicWriter.delayFile(kind, True, True)

# %%
graphicWriter.delayFile(kind, True, False)

# %%
graphicWriter.jitterFile(kind, True, True)

# %%
graphicWriter.fairnessFile(kind, True, True)

# %%
graphicWriter.fairnessFile(kind, True, False)

# %%
graphicWriter.plrFile(kind, True, True)

# %%
graphicWriter.plrFile(kind, True, False)

# %% [markdown]
# # CBR

# %%
kind = "CBR"

# %%
graphicWriter.gputFile(kind, True, True)

# %%
graphicWriter.delayFile(kind, True, True)

# %%
graphicWriter.jitterFile(kind, True, True)

# %%
graphicWriter.fairnessFile(kind, True, True)

# %%
graphicWriter.plrFile(kind, True, True)

# %% [markdown]
# # Loss Ratio

# %%
import pandas as pd
averagePacketLoss = {}
for key in metrics["GERAL"]["PLR"]:
    averagePacketLoss[key] = []
    for i in range(0, 5):
        average = sum(metrics["GERAL"]["PLR"][key][i])/len(metrics["GERAL"]["PLR"][key][i])
        averagePacketLoss[key].append(average)

# %%
dfLossRatio = pd.DataFrame({'PF': averagePacketLoss[1],
                            'FLS': averagePacketLoss[4], 'EXPR': averagePacketLoss[5], 'LOGR': averagePacketLoss[6],
                           'EXPFLS': averagePacketLoss[7], 'LOGFLS': averagePacketLoss[8]},
                           index=[10,20,30,40,50])
plot = dfLossRatio.plot.bar(rot=0)
plot.set(xlabel="Usuários", ylabel="Perda de pacotes (%)")
plot.legend(loc='best', bbox_to_anchor=(1.0, 0.5))
fig = plot.get_figure()
fig.savefig(graphicsbase + "PacketLossRatio.pdf", bbox_inches='tight')
